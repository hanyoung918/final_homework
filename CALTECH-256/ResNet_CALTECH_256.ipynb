# %% [markdown]
# <a href="https://colab.research.google.com/github/hanyoung918/final_homework/blob/master/CALTECH-256/ResNet_CALTECH_256.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')

image_size = (128, 128)
path = '/content/gdrive/MyDrive/Colab Notebooks/ResNet_졸과/GP/pickle_256'
# Out:
# Mounted at /content/gdrive

# %%
"""
ResNet v1
[a] Deep Residual Learning for Image Recognition
https://arxiv.org/pdf/1512.03385.pdf
ResNet v2
[b] Identity Mappings in Deep Residual Networks
https://arxiv.org/pdf/1603.05027.pdf

https://github.com/dnrghks5583/Way-that-set-threshold-for-setting-PMD/blob/main/Caltech101/caltech101_resnet.ipynb
"""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input
from tensorflow.keras.layers import Flatten, add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
import numpy as np
import os
import math

# training parameters
batch_size = 128 # orig paper trained all networks with batch_size=128
epochs = 100
num_classes = 257
data_augmentation = True
learning_rate_variable = 3 # initial learning rate : 1e-learning rate, originally 3
checkpoint_directory = 'CALTECH-256_no_augmentation_models_with_lr_e-' + str(learning_rate_variable) #not modified version saved at 'CALTECH-256_saved_models'

# subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 9

# model version
# orig paper: version = 1 (ResNet v1), 
# improved ResNet: version = 2 (ResNet v2)
version = 1

# %%
import gzip
import pickle

os.chdir(path)

with gzip.open('caltech256_x_trainData.pickle', 'rb') as f:
    x_train = pickle.load(f)
    
with gzip.open('caltech256_x_testData.pickle', 'rb') as f:
    x_test = pickle.load(f)
    
with gzip.open('caltech256_y_trainData.pickle', 'rb') as f:
    y_train = pickle.load(f)
    
with gzip.open('caltech256_y_testData.pickle', 'rb') as f:
    y_test = pickle.load(f)

# %%
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# input image dimensions.
input_shape = x_train.shape[1:]

# normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# if subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('Model_Type : ' , model_type)
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# convert class vectors to binary class matrices.
#y_train = to_categorical(y_train, num_classes)
#y_test = to_categorical(y_test, num_classes)
# Out:
# Model_Type :  ResNet56v1
# x_train shape: (24485, 128, 128, 3)
# 24485 train samples
# 6122 test samples
# y_train shape: (24485, 257)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    lr = 1*(10**(-learning_rate_variable)) #originally 3
    if epoch > 180:
        lr *= 0.5*(10**(-learning_rate_variable)) #originally 3
    elif epoch > 160:
        lr *= 1*(10**(-learning_rate_variable)) #originally 3
    elif epoch > 120:
        lr *= 1*(10**(-learning_rate_variable+1)) #originally 2
    elif epoch > 80:
        lr *= 1*(10**(-learning_rate_variable+2)) #originally 1
    print('Learning rate: ', lr)
    return lr


def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder
    Arguments:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)
    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=num_classes):
    """ResNet Version 1 Model builder [a]
    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved
    (downsampled) by a convolutional layer with strides=2, while 
    the number of filters is doubled. Within each stage, 
    the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M
    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, in [a])')
    # start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            # first layer but not first stack
            if stack > 0 and res_block == 0:  
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            # first layer but not first stack
            if stack > 0 and res_block == 0:
                # linear projection residual shortcut
                # connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=num_classes):
    """ResNet Version 2 Model builder [b]
    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or 
    also known as bottleneck layer.
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, 
    the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, 
    while the number of filter maps is
    doubled. Within each stage, the layers have 
    the same number filters and the same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256
    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 110 in [b])')
    # start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU
    # on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                # first layer and first stage
                if res_block == 0:  
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                # first layer but not first stage
                if res_block == 0:
                    # downsample
                    strides = 2 

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection
                # to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = add([x, y])

        num_filters_in = num_filters_out

    # add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['acc'])
model.summary()

# enable this if pydot can be installed
# pip install pydot
#plot_model(model, to_file="%s.png" % model_type, show_shapes=True)
print(model_type)
# Out:
# Learning rate:  0.001
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 128, 128, 16) 0           activation[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 16) 0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 16) 2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 16) 64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 16) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 16) 2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 16) 64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 16) 0           activation_2[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128, 128, 16) 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 16) 2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 16) 64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 16) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 16) 2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 128, 16) 64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 128, 128, 16) 0           activation_4[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 128, 16) 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 128, 128, 16) 2320        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 16) 64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128, 128, 16) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 128, 128, 16) 2320        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 128, 128, 16) 64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 128, 16) 0           activation_6[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 128, 128, 16) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 128, 16) 2320        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 128, 128, 16) 64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 128, 128, 16) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 128, 16) 2320        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128, 128, 16) 64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 128, 16) 0           activation_8[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128, 128, 16) 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 128, 128, 16) 2320        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128, 128, 16) 64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 128, 128, 16) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 16) 2320        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 128, 128, 16) 64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 128, 128, 16) 0           activation_10[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 128, 128, 16) 0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 16) 2320        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128, 128, 16) 64          conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 128, 128, 16) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 16) 2320        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128, 128, 16) 64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 128, 128, 16) 0           activation_12[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 128, 128, 16) 0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 16) 2320        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 128, 16) 64          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 128, 16) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 16) 2320        activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 16) 64          conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 128, 128, 16) 0           activation_14[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 128, 128, 16) 0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 16) 2320        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 16) 64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 128, 128, 16) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 16) 2320        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128, 128, 16) 64          conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 128, 128, 16) 0           activation_16[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 128, 128, 16) 0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 32)   4640        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 64, 32)   128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 64, 32)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 32)   9248        activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 32)   544         activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 64, 64, 32)   128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 64, 32)   0           conv2d_21[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 64, 64, 32)   0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 32)   9248        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 64, 32)   128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 64, 64, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 32)   9248        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, 64, 32)   128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 64, 64, 32)   0           activation_20[0][0]
#                                                                  batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 64, 32)   0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 32)   9248        activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 64, 64, 32)   128         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 64, 64, 32)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 32)   9248        activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64, 64, 32)   128         conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64, 64, 32)   0           activation_22[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 64, 64, 32)   0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 32)   9248        activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 64, 64, 32)   128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 64, 64, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 32)   9248        activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 64, 64, 32)   128         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 64, 64, 32)   0           activation_24[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 64, 64, 32)   0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 64, 32)   9248        activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 64, 64, 32)   128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 64, 64, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 32)   9248        activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 64, 64, 32)   128         conv2d_29[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 64, 32)   0           activation_26[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 64, 64, 32)   0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 64, 32)   9248        activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 64, 64, 32)   128         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 64, 64, 32)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 32)   9248        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 64, 64, 32)   128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 64, 64, 32)   0           activation_28[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 64, 64, 32)   0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 32)   9248        activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 64, 64, 32)   128         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 64, 64, 32)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, 64, 32)   9248        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 64, 64, 32)   128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 64, 64, 32)   0           activation_30[0][0]
#                                                                  batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 64, 64, 32)   0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 64, 32)   9248        activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 64, 64, 32)   128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 64, 64, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 32)   9248        activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 64, 64, 32)   128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 64, 64, 32)   0           activation_32[0][0]
#                                                                  batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 64, 64, 32)   0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 32)   9248        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 64, 64, 32)   128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 64, 64, 32)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 32)   9248        activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 64, 64, 32)   128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 64, 64, 32)   0           activation_34[0][0]
#                                                                  batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 64, 64, 32)   0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 32, 32, 64)   18496       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 32, 32, 64)   256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 32, 32, 64)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 32, 32, 64)   36928       activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 32, 32, 64)   2112        activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 32, 32, 64)   256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 32, 32, 64)   0           conv2d_40[0][0]
#                                                                  batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 32, 32, 64)   0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 32, 32, 64)   36928       activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 32, 32, 64)   256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 64)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 32, 32, 64)   36928       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 32, 32, 64)   256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 32, 64)   0           activation_38[0][0]
#                                                                  batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 64)   0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 32, 32, 64)   36928       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 32, 32, 64)   256         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 32, 64)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 32, 64)   36928       activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 32, 32, 64)   256         conv2d_44[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 64)   0           activation_40[0][0]
#                                                                  batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 32, 64)   0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 64)   36928       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 32, 32, 64)   256         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 32, 64)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 64)   36928       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 32, 32, 64)   256         conv2d_46[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 32, 32, 64)   0           activation_42[0][0]
#                                                                  batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 32, 64)   0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 64)   36928       activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 32, 32, 64)   256         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 32, 64)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 64)   36928       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 32, 32, 64)   256         conv2d_48[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 32, 32, 64)   0           activation_44[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 32, 32, 64)   0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 64)   36928       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 32, 32, 64)   256         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 32, 32, 64)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 64)   36928       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 32, 32, 64)   256         conv2d_50[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 32, 32, 64)   0           activation_46[0][0]
#                                                                  batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 32, 32, 64)   0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 64)   36928       activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 32, 32, 64)   256         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 32, 32, 64)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 64)   36928       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 32, 32, 64)   256         conv2d_52[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 32, 32, 64)   0           activation_48[0][0]
#                                                                  batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 32, 32, 64)   0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 32, 32, 64)   36928       activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 32, 32, 64)   256         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 32, 32, 64)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 32, 32, 64)   36928       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 32, 32, 64)   256         conv2d_54[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 32, 32, 64)   0           activation_50[0][0]
#                                                                  batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 32, 32, 64)   0           add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 32, 32, 64)   36928       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 32, 32, 64)   256         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 32, 32, 64)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 32, 32, 64)   36928       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 32, 32, 64)   256         conv2d_56[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 32, 32, 64)   0           activation_52[0][0]
#                                                                  batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 32, 32, 64)   0           add_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 4, 4, 64)     0           activation_54[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 257)          263425      flatten[0][0]
# ==================================================================================================
# Total params: 1,124,545
# Trainable params: 1,120,481
# Non-trainable params: 4,064
# __________________________________________________________________________________________________
# ResNet56v1

# %%
# prepare model model saving directory.

save_dir = os.path.join(os.getcwd(), checkpoint_directory)
model_name = 'CALTECH-256_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=False) #initial True

# %%
lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

#callbacks = [lr_reducer, lr_scheduler]
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # this will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False)    
    # compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    steps_per_epoch =  math.ceil(len(x_train) / batch_size)
    # fit the model on the batches generated by datagen.flow().
    model.fit(x=datagen.flow(x_train, y_train, batch_size=batch_size),
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),
              steps_per_epoch=steps_per_epoch,
              callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/100
# Learning rate:  0.001
# 192/192 [==============================] - 129s 633ms/step - loss: 5.9918 - acc: 0.0629 - val_loss: 5.6126 - val_acc: 0.0634
#
# Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.001.h5
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/100
# Learning rate:  0.001
# 192/192 [==============================] - 121s 627ms/step - loss: 4.9976 - acc: 0.1271 - val_loss: 4.8450 - val_acc: 0.1517
#
# Epoch 00002: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.002.h5
# Epoch 3/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 4.5451 - acc: 0.1795 - val_loss: 4.5186 - val_acc: 0.1931
#
# Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.003.h5
# Epoch 4/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 4.2185 - acc: 0.2203 - val_loss: 4.2669 - val_acc: 0.2262
#
# Epoch 00004: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.004.h5
# Epoch 5/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 631ms/step - loss: 3.9537 - acc: 0.2555 - val_loss: 4.1472 - val_acc: 0.2568
#
# Epoch 00005: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.005.h5
# Epoch 6/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 3.7499 - acc: 0.2834 - val_loss: 3.9322 - val_acc: 0.2883
#
# Epoch 00006: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.006.h5
# Epoch 7/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 3.5506 - acc: 0.3144 - val_loss: 3.7790 - val_acc: 0.3001
#
# Epoch 00007: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.007.h5
# Epoch 8/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 3.3634 - acc: 0.3419 - val_loss: 3.7369 - val_acc: 0.3113
#
# Epoch 00008: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.008.h5
# Epoch 9/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 3.2065 - acc: 0.3662 - val_loss: 3.5992 - val_acc: 0.3314
#
# Epoch 00009: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.009.h5
# Epoch 10/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 3.0588 - acc: 0.3900 - val_loss: 3.3933 - val_acc: 0.3522
#
# Epoch 00010: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.010.h5
# Epoch 11/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 2.9228 - acc: 0.4102 - val_loss: 3.7779 - val_acc: 0.3528
#
# Epoch 00011: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.011.h5
# Epoch 12/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 2.8219 - acc: 0.4278 - val_loss: 3.9508 - val_acc: 0.3362
#
# Epoch 00012: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.012.h5
# Epoch 13/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 2.7121 - acc: 0.4439 - val_loss: 3.4862 - val_acc: 0.3804
#
# Epoch 00013: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.013.h5
# Epoch 14/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 2.6189 - acc: 0.4611 - val_loss: 3.3811 - val_acc: 0.3765
#
# Epoch 00014: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.014.h5
# Epoch 15/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 631ms/step - loss: 2.5390 - acc: 0.4765 - val_loss: 3.1840 - val_acc: 0.4051
#
# Epoch 00015: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.015.h5
# Epoch 16/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 2.4515 - acc: 0.4880 - val_loss: 3.1661 - val_acc: 0.4059
#
# Epoch 00016: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.016.h5
# Epoch 17/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 2.3844 - acc: 0.5026 - val_loss: 3.2669 - val_acc: 0.3989
#
# Epoch 00017: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.017.h5
# Epoch 18/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 2.3124 - acc: 0.5126 - val_loss: 3.2591 - val_acc: 0.4028
#
# Epoch 00018: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.018.h5
# Epoch 19/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 631ms/step - loss: 2.2359 - acc: 0.5313 - val_loss: 3.1914 - val_acc: 0.4085
#
# Epoch 00019: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.019.h5
# Epoch 20/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 631ms/step - loss: 2.1804 - acc: 0.5392 - val_loss: 3.1992 - val_acc: 0.4167
#
# Epoch 00020: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.020.h5
# Epoch 21/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 2.1277 - acc: 0.5467 - val_loss: 3.2211 - val_acc: 0.4270
#
# Epoch 00021: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.021.h5
# Epoch 22/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 2.0591 - acc: 0.5628 - val_loss: 3.0814 - val_acc: 0.4329
#
# Epoch 00022: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.022.h5
# Epoch 23/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.9997 - acc: 0.5732 - val_loss: 3.1855 - val_acc: 0.4164
#
# Epoch 00023: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.023.h5
# Epoch 24/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.9546 - acc: 0.5810 - val_loss: 3.1766 - val_acc: 0.4170
#
# Epoch 00024: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.024.h5
# Epoch 25/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.8899 - acc: 0.5951 - val_loss: 3.2004 - val_acc: 0.4257
#
# Epoch 00025: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.025.h5
# Epoch 26/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.8557 - acc: 0.6022 - val_loss: 3.2159 - val_acc: 0.4232
#
# Epoch 00026: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.026.h5
# Epoch 27/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.7973 - acc: 0.6127 - val_loss: 3.1704 - val_acc: 0.4497
#
# Epoch 00027: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.027.h5
# Epoch 28/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.7641 - acc: 0.6168 - val_loss: 3.1110 - val_acc: 0.4441
#
# Epoch 00028: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.028.h5
# Epoch 29/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.7563 - acc: 0.6178 - val_loss: 3.1261 - val_acc: 0.4397
#
# Epoch 00029: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.029.h5
# Epoch 30/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 631ms/step - loss: 1.6913 - acc: 0.6359 - val_loss: 3.1003 - val_acc: 0.4512
#
# Epoch 00030: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.030.h5
# Epoch 31/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.6584 - acc: 0.6410 - val_loss: 3.2678 - val_acc: 0.4467
#
# Epoch 00031: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.031.h5
# Epoch 32/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.6221 - acc: 0.6503 - val_loss: 3.6495 - val_acc: 0.4306
#
# Epoch 00032: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.032.h5
# Epoch 33/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.5890 - acc: 0.6566 - val_loss: 3.2704 - val_acc: 0.4495
#
# Epoch 00033: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.033.h5
# Epoch 34/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.5439 - acc: 0.6629 - val_loss: 3.1484 - val_acc: 0.4405
#
# Epoch 00034: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.034.h5
# Epoch 35/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.5279 - acc: 0.6688 - val_loss: 3.2609 - val_acc: 0.4443
#
# Epoch 00035: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.035.h5
# Epoch 36/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.4945 - acc: 0.6782 - val_loss: 3.4081 - val_acc: 0.4454
#
# Epoch 00036: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.036.h5
# Epoch 37/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.4550 - acc: 0.6843 - val_loss: 3.4351 - val_acc: 0.4508
#
# Epoch 00037: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.037.h5
# Epoch 38/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.4347 - acc: 0.6851 - val_loss: 3.8730 - val_acc: 0.4404
#
# Epoch 00038: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.038.h5
# Epoch 39/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.4110 - acc: 0.6917 - val_loss: 3.2373 - val_acc: 0.4502
#
# Epoch 00039: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.039.h5
# Epoch 40/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.3769 - acc: 0.7006 - val_loss: 3.2637 - val_acc: 0.4530
#
# Epoch 00040: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.040.h5
# Epoch 41/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.3582 - acc: 0.7074 - val_loss: 3.4079 - val_acc: 0.4520
#
# Epoch 00041: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.041.h5
# Epoch 42/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.3357 - acc: 0.7063 - val_loss: 3.2800 - val_acc: 0.4603
#
# Epoch 00042: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.042.h5
# Epoch 43/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.2999 - acc: 0.7195 - val_loss: 3.6355 - val_acc: 0.4577
#
# Epoch 00043: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.043.h5
# Epoch 44/100
# Learning rate:  0.001
# 192/192 [==============================] - 122s 632ms/step - loss: 1.2794 - acc: 0.7261 - val_loss: 3.3979 - val_acc: 0.4512
#
# Epoch 00044: saving model to /content/gdrive/My Drive/Colab Notebooks/ResNet_졸과/GP/pickle_256/CALTECH-256_no_augmentation_models_with_lr_e-3/CALTECH-256_ResNet56v1_model.044.h5
# Epoch 45/100
# Learning rate:  0.001
#  73/192 [==========>...................] - ETA: 1:10 - loss: 1.2006 - acc: 0.7469

# %%
# score trained model
scores = model.evaluate(x_test,
                        y_test,
                        batch_size=batch_size,
                        verbose=0)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
